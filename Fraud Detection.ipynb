# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %%
# Calculating percent of missing values in columns
df_missing_columns = (round(((df.isnull().sum()/len(df.index))*100),2).to_frame('null')).sort_values('null', ascending=False)
df_missing_columns
# Out:
#         null
# Time     0.0
# V16      0.0
# Amount   0.0
# V28      0.0
# V27      0.0
# V26      0.0
# V25      0.0
# V24      0.0
# V23      0.0
# V22      0.0
# V21      0.0
# V20      0.0
# V19      0.0
# V18      0.0
# V17      0.0
# V15      0.0
# V1       0.0
# V14      0.0
# V13      0.0
# V12      0.0
# V11      0.0
# V10      0.0
# V9       0.0
# V8       0.0
# V7       0.0
# V6       0.0
# V5       0.0
# V4       0.0
# V3       0.0
# V2       0.0
# Class    0.0

# %% [markdown]
# No missing values in any column. Hence, there is no problem with null values in the dataset.

# %%
classes = df['Class'].value_counts()
classes
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
normal_share = round((classes[0]/df['Class'].count()*100),2)
normal_share
# Out:
# 99.83

# %%
fraud_share = round((classes[1]/df['Class'].count()*100),2)
fraud_share
# Out:
# 0.17

# %% [markdown]
# **There are only 0.17% frauds.Hence, there is class imbalance.**

# %%
# Bar plot for the percentage of fraudulent vs non-fraudulent transcations
fraud_percentage = {'Class':['Non-Fraudulent', 'Fraudulent'], 'Percentage':[normal_share, fraud_share]} 
df_fraud_percentage = pd.DataFrame(fraud_percentage) 
sns.barplot(x='Class',y='Percentage', data=df_fraud_percentage, palette='Reds')
plt.title('Percentage of fraudulent vs non-fraudulent transcations')
plt.show()

# %%
#distribution of classes with time
#creating fraudulent and non fraudulent dataframe
data_fraud = df[df['Class'] == 1]
data_non_fraud = df[df['Class'] == 0]

plt.figure(figsize=(8,5))
ax = sns.distplot(data_fraud['Time'],hist=False)
ax = sns.distplot(data_non_fraud['Time'],hist=False)
ax.set(xlabel='Seconds elapsed between the transction and the first transction')
ax.set(ylabel='')
plt.legend(['Fradulent','Non Fradulent'], loc=0)
plt.show()

# %%
#There is no evident pattern for the transactions with respect to time. Hence, we drop the time column
df.drop('Time', axis=1, inplace=True)

# %%
#distribution of classes with amount
plt.figure(figsize=(8,5))

ax = sns.distplot(data_fraud['Amount'],hist=False)
ax = sns.distplot(data_non_fraud['Amount'],hist=False)
ax.set(xlabel='Transction Amount')
ax.set(ylabel='')
ylabels = [str(int(y))+'K' for y in ax.get_xticks()/1000]
ax.set_yticklabels(ylabels)
plt.legend(['Fradulent','Non Fradulent'], loc=0)
plt.show()

# %% [markdown]
# Fraudulent transctions are mostly densed in the lower range of amount.
# Non-fraudulent transctions are spread throughout low to high range of amount.

# %%
<font size="4">**Train-test-split**</font>

# %%
#Splitting data into train and test set 80:20
from sklearn.model_selection import train_test_split
X = df.drop(['Class'], axis=1)
y = df['Class']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=100)

# %% [markdown]
# <font size="4">**Feature Scaling**</font>

# %%
#We need to scale only Amount column as all other columns are already scaled by the PCA transformation.
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# Fit the data into scaler and transform
X_train['Amount'] = scaler.fit_transform(X_train[['Amount']])
X_train.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 201788  2.023734 -0.429219 -0.691061 -0.201461 -0.162486  0.283718 -0.674694
# 179369 -0.145286  0.736735  0.543226  0.892662  0.350846  0.089253  0.626708
# 73138  -3.015846 -1.920606  1.229574  0.721577  1.089918 -0.195727 -0.462586
# 208679  1.851980 -1.007445 -1.499762 -0.220770 -0.568376 -1.232633  0.248573
# 206534  2.237844 -0.551513 -1.426515 -0.924369 -0.401734 -1.438232 -0.119942
#
#               V8        V9       V10  ...       V20       V21       V22  \
# 201788  0.192230  1.124319 -0.037763  ... -0.171390 -0.195207 -0.477813
# 179369 -0.049137 -0.732566  0.297692  ...  0.206709 -0.124288 -0.263560
# 73138   0.919341 -0.612193 -0.966197  ...  0.842838  0.274911 -0.319550
# 208679 -0.539483 -0.813368  0.785431  ... -0.196551 -0.406722 -0.899081
# 206534 -0.449263 -0.717258  0.851668  ... -0.045417  0.050447  0.125601
#
# ...

# %%
# Transform the test set
X_test['Amount'] = scaler.transform(X_test[['Amount']])
X_test.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 49089   1.229452 -0.235478 -0.627166  0.419877  1.797014  4.069574 -0.896223
# 154704  2.016893 -0.088751 -2.989257 -0.142575  2.675427  3.332289 -0.652336
# 67247   0.535093 -1.469185  0.868279  0.385462 -1.439135  0.368118 -0.499370
# 251657  2.128486 -0.117215 -1.513910  0.166456  0.359070 -0.540072  0.116023
# 201903  0.558593  1.587908 -2.368767  5.124413  2.171788 -0.500419  1.059829
#
#               V8        V9       V10  ...       V20       V21       V22  \
# 49089   1.036103  0.745991 -0.147304  ... -0.057922 -0.170060 -0.288750
# 154704  0.752811  1.962566 -1.025024  ... -0.147619 -0.184153 -0.089661
# 67247   0.303698  1.042073 -0.437209  ...  0.437685  0.028010 -0.384708
# 251657 -0.216140  0.680314  0.079977  ... -0.227278 -0.357993 -0.905085
# 201903 -0.254233 -1.959060  0.948915  ...  0.249457 -0.035049  0.271455
#
# ...

# %% [markdown]
# <font size="4">**Skewness check**</font>

# %%
cols = X_train.columns
cols
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'],
#       dtype='object')

# %%
# Plotting the distribution of the variables
k=0
plt.figure(figsize=(17,28))
for col in cols :    
    k=k+1
    plt.subplot(6, 5,k)    
    sns.distplot(X_train[col])
    plt.title(col+' '+str(X_train[col].skew()))

# %%
#We will mitigate the skewness for variables that are heavily skewed by importing PowerTransformer
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer(method='yeo-johnson', standardize=True, copy=False)
# Fit and transform the classifier on training data
X_train[cols] = pt.fit_transform(X_train)
# Transform the test set
X_test[cols] = pt.transform(X_test)

# %%
# Plotting the distribution of the variables again
k=0
plt.figure(figsize=(17,28))
for col in cols :    
    k=k+1
    plt.subplot(6, 5,k)    
    sns.distplot(X_train[col])
    plt.title(col+' '+str(X_train[col].skew()))

# %% [markdown]
# Variables are normally distributed after the transformation

# %% [markdown]
# <font size="5">**Building baseline models on imbalanced data**</font>

# %% [markdown]
# <font size="5">**1. Logistic Regression**</font>

# %%
# Importing scikit logistic regression module and metrics
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report

# %% [markdown]
# <font size="4">**1a. Tuning hyperparameter C**</font>

# %%
# Importing libraries for cross validation
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
# Creating KFold object with 5 splits
folds = KFold(n_splits=5, shuffle=True, random_state=4)

# Specify params
params = {"C": [0.01, 0.1, 1, 10, 100, 1000]}
model_cv = GridSearchCV(estimator = LogisticRegression(),
                        param_grid = params, 
                        scoring= 'roc_auc', 
                        cv = folds, 
                        verbose = 1,
                        return_train_score=True) 

# Fit the model
model_cv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=4, shuffle=True),
#              estimator=LogisticRegression(),
#              param_grid={'C': [0.01, 0.1, 1, 10, 100, 1000]},
#              return_train_score=True, scoring='roc_auc', verbose=1)

# %%
# results of grid search CV
cv_results = pd.DataFrame(model_cv.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.200256      0.011012         0.010949        0.000788    0.01
# 1       0.262239      0.013823         0.011244        0.001029     0.1
# 2       0.271398      0.024507         0.010374        0.000513       1
# 3       0.281525      0.017284         0.010509        0.000535      10
# 4       0.274272      0.024597         0.010937        0.001546     100
# 5       0.269291      0.024684         0.011032        0.000995    1000
#
#         params  split0_test_score  split1_test_score  split2_test_score  \
# 0  {'C': 0.01}           0.986856           0.987234           0.968390
# 1   {'C': 0.1}           0.986104           0.987144           0.960929
# 2     {'C': 1}           0.985834           0.986806           0.958452
# 3    {'C': 10}           0.985798           0.986754           0.958181
# 4   {'C': 100}           0.985793           0.986748           0.958155
# ...

# %%
# plot of C versus train and validation scores

plt.figure(figsize=(8, 6))
plt.plot(cv_results['param_C'], cv_results['mean_test_score'])
plt.plot(cv_results['param_C'], cv_results['mean_train_score'])
plt.xlabel('C')
plt.ylabel('roc_auc')
plt.legend(['test result', 'train result'], loc=0)
plt.xscale('log')

# %%
# Best score with best C
best_score = model_cv.best_score_
best_C = model_cv.best_params_['C']

print(" The highest test roc_auc is {0} at C = {1}".format(best_score, best_C))
# Out:
#  The highest test roc_auc is 0.9837192853831933 at C = 0.01

# %% [markdown]
# <font size="4">**1b. Logistic regression with optimal C**</font>

# %%
# Instantiate the model with best C
logistic_imb = LogisticRegression(C=0.01)

# Fit the model on the train set
logistic_imb_model = logistic_imb.fit(X_train, y_train)

# %% [markdown]
# <font size="3">**Predictions on the train set**</font>

# %%
# Predictions on the train set
y_train_pred = logistic_imb_model.predict(X_train)

# Confusion matrix
confusion = metrics.confusion_matrix(y_train, y_train_pred)
print(confusion)
# Out:
# [[227427     22]
#  [   135    261]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_train, y_train_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))

# F1 score
print("F1-Score:-", f1_score(y_train, y_train_pred))
# Out:
# Accuracy:- 0.9993109350655051
# Precision:- 0.9222614840989399
# Recall:- 0.6590909090909091
# F1-Score:- 0.7687776141384388

# %%
# classification_report
print(classification_report(y_train, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227449
#            1       0.92      0.66      0.77       396
#
#     accuracy                           1.00    227845
#    macro avg       0.96      0.83      0.88    227845
# weighted avg       1.00      1.00      1.00    227845

# %% [markdown]
# <font size="3">ROC on the train set</font>

# %%
# ROC Curve function

def draw_roc( actual, probs ):
    fpr, tpr, thresholds = metrics.roc_curve( actual, probs,
                                              drop_intermediate = False )
    auc_score = metrics.roc_auc_score( actual, probs )
    plt.figure(figsize=(5, 5))
    plt.plot( fpr, tpr, label='ROC curve (area = %0.2f)' % auc_score )
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

    return None

# %%
# Predicted probability
y_train_pred_proba = logistic_imb_model.predict_proba(X_train)[:,1]

# %%
# Plot the ROC curve
draw_roc(y_train, y_train_pred_proba)

# %% [markdown]
# This is a very good ROC on the train set.

# %% [markdown]
# <font size="3">**Predictions on the test set**</font>

# %%
# Prediction on the test set
y_test_pred = logistic_imb_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[56850    16]
#  [   42    54]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))

# F1 score
print("F1-Score:-", f1_score(y_test, y_test_pred))
# Out:
# Accuracy:- 0.9989817773252344
# Precision:- 0.7714285714285715
# Recall:- 0.5625
# F1-Score:- 0.6506024096385543

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56866
#            1       0.77      0.56      0.65        96
#
#     accuracy                           1.00     56962
#    macro avg       0.89      0.78      0.83     56962
# weighted avg       1.00      1.00      1.00     56962

# %% [markdown]
# <font size="3">ROC on the test set</font>

# %%
# Predicted probability
y_test_pred_proba = logistic_imb_model.predict_proba(X_test)[:,1]

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# This is a very good ROC on the test set 0.97, which is almost close to 1.

# %% [markdown]
# <font size="4">**Model summary - Logistic Regression**</font>
#
# - <font size="4">**Train set**</font>
#
#     - <font size="3">Accuracy:- 0.999</font>
#
#     - <font size="3">Precision:- 0.922</font>
#
#     - <font size="3">Recall:- 0.659</font>
#
#     - <font size="3">F1-Score:- 0.769</font>
#
#     - <font size="3">ROC :- 0.99</font>
#
#
# - <font size="3">**Test set**</font>
#
#     - <font size="3">Accuracy:- 0.998</font>
#
#     - <font size="3">Precision:- 0.771</font>
#
#     - <font size="3">Recall:- 0.562</font>
#
#     - <font size="3">F1-Score:- 0.651</font>
#
#     - <font size="3">ROC :- 0.97</font>
#
#
# <font size="3">Overall, the model is performing well in the test set.</font>

# %% [markdown]
# <font size="5">**2. Decision Tree**</font>

# %%
# Importing decision tree classifier
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# <font size="4">**2a. Tuning hyperparameters**</font>

# %%
# Create the parameter grid 
param_grid = {
    'max_depth': range(5, 15, 5),
    'min_samples_leaf': range(50, 150, 50),
    'min_samples_split': range(50, 150, 50),
}


# Instantiate the grid search model
dtree = DecisionTreeClassifier()

grid_search = GridSearchCV(estimator = dtree, 
                           param_grid = param_grid, 
                           scoring= 'roc_auc',
                           cv = 3, 
                           verbose = 1)

# Fit the grid search to the data
grid_search.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': range(5, 15, 5),
#                          'min_samples_leaf': range(50, 150, 50),
#                          'min_samples_split': range(50, 150, 50)},
#              scoring='roc_auc', verbose=1)

# %%
# cv results
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       2.292831      0.007376         0.012070        0.000424
# 1       2.298853      0.007741         0.011420        0.000211
# 2       2.297940      0.008191         0.011566        0.000257
# 3       2.302465      0.005328         0.011451        0.000276
# 4       4.538439      0.009999         0.012589        0.000095
# 5       4.531327      0.006090         0.012632        0.000146
# 6       4.527579      0.036074         0.012772        0.000111
# 7       4.541083      0.005745         0.012945        0.000401
#
#   param_max_depth param_min_samples_leaf param_min_samples_split  \
# 0               5                     50                      50
# 1               5                     50                     100
# 2               5                    100                      50
# 3               5                    100                     100
# ...

# %%
# Printing the optimal sensitivity score and hyperparameters
print("Best roc_auc:-", grid_search.best_score_)
print(grid_search.best_estimator_)
# Out:
# Best roc_auc:- 0.9382050164508641
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=100, min_samples_split=50)

# %% [markdown]
# <font size="4">**2b. Decision Tree model with optimal hyperparameters**</font>

# %%
# Model with optimal hyperparameters
dt_imb_model = DecisionTreeClassifier(criterion = "gini", 
                                  random_state = 100,
                                  max_depth=5, 
                                  min_samples_leaf=100,
                                  min_samples_split=100)

dt_imb_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=100, min_samples_split=100,
#                        random_state=100)

# %% [markdown]
# <font size="3">**Predictions on the train set**</font>

# %%
# Predictions on the train set
y_train_pred = dt_imb_model.predict(X_train)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_train, y_train)
print(confusion)
# Out:
# [[227449      0]
#  [     0    396]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_train, y_train_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))

# F1 score
print("F1-Score:-", f1_score(y_train, y_train_pred))
# Out:
# Accuracy:- 0.9991704887094297
# Precision:- 1.0
# Recall:- 1.0
# F1-Score:- 0.7490039840637449

# %%
# classification_report
print(classification_report(y_train, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227449
#            1       0.79      0.71      0.75       396
#
#     accuracy                           1.00    227845
#    macro avg       0.89      0.86      0.87    227845
# weighted avg       1.00      1.00      1.00    227845

# %%
# Predicted probability
y_train_pred_proba = dt_imb_model.predict_proba(X_train)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_train, y_train_pred_proba)
auc
# Out:
# 0.9534547393930157

# %%
# Plot the ROC curve
draw_roc(y_train, y_train_pred_proba)

# %% [markdown]
# <font size="3">**Predictions on the test set**</font>

# %%
# Predictions on the test set
y_test_pred = dt_imb_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[56836    30]
#  [   40    56]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))

# F1 score
print("F1-Score:-", f1_score(y_train, y_train_pred))
# Out:
# Accuracy:- 0.9987711105649381
# Precision:- 0.6511627906976745
# Recall:- 0.5833333333333334
# F1-Score:- 0.7490039840637449

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56866
#            1       0.65      0.58      0.62        96
#
#     accuracy                           1.00     56962
#    macro avg       0.83      0.79      0.81     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
# Predicted probability
y_test_pred_proba = dt_imb_model.predict_proba(X_test)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_test, y_test_pred_proba)
auc
# Out:
# 0.92174979703748

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# <font size="4">**Model summary - Decision Tree**</font>
#
# - <font size="4">**Train set**</font>
#
#     - <font size="3">Accuracy:- 0.999</font>
#
#     - <font size="3">Precision:- 1.0</font>
#
#     - <font size="3">Recall:- 1.0</font>
#
#     - <font size="3">F1-Score:- 0.749</font>
#
#     - <font size="3">ROC :- 0.95</font>
#
#
# - <font size="3">**Test set**</font>
#
#     - <font size="3">Accuracy:- 0.998</font>
#
#     - <font size="3">Precision:- 0.651</font>
#
#     - <font size="3">Recall:- 0.583</font>
#
#     - <font size="3">F1-Score:- 0.749</font>
#
#     - <font size="3">ROC :- 0.92</font>

# %% [markdown]
# <font size="5">**3. Random Forest**</font>

# %%
# Importing random forest classifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# <font size="4">**3a. Tuning hyperparameters**</font>

# %%
param_grid = {
    'max_depth': range(5,10,5),
    'min_samples_leaf': range(50, 150, 50),
    'min_samples_split': range(50, 150, 50),
    'n_estimators': [100,200,300], 
    'max_features': [10, 20]
}
# Create a based model
rf = RandomForestClassifier()
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rf, 
                           param_grid = param_grid, 
                           cv = 2,
                           n_jobs = -1,
                           verbose = 1, 
                           return_train_score=True)

# Fit the model
grid_search.fit(X_train, y_train)
# Out:
# Fitting 2 folds for each of 24 candidates, totalling 48 fits
# GridSearchCV(cv=2, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': range(5, 10, 5), 'max_features': [10, 20],
#                          'min_samples_leaf': range(50, 150, 50),
#                          'min_samples_split': range(50, 150, 50),
#                          'n_estimators': [100, 200, 300]},
#              return_train_score=True, verbose=1)

# %%
# optimal accuracy score and hyperparameters
print('We can get accuracy of',grid_search.best_score_,'using',grid_search.best_params_)
# Out:
# We can get accuracy of 0.9992933790590904 using {'max_depth': 5, 'max_features': 10, 'min_samples_leaf': 50, 'min_samples_split': 100, 'n_estimators': 300}

# %% [markdown]
# <font size="4">**3b. Random Forest model with optimal hyperparameters**</font>

# %%
# model with the best hyperparameters

rfc_imb_model = RandomForestClassifier(bootstrap=True,
                             max_depth=5,
                             min_samples_leaf=50, 
                             min_samples_split=50,
                             max_features=10,
                             n_estimators=100)

# %%
# Fit the model
rfc_imb_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, max_features=10, min_samples_leaf=50,
#                        min_samples_split=50)

# %% [markdown]
# <font size="3">**Predictions on the train set**</font>

# %%
# Predictions on the train set
y_train_pred = rfc_imb_model.predict(X_train)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_train, y_train)
print(confusion)
# Out:
# [[227449      0]
#  [     0    396]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_train, y_train_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))

# F1 score
print("F1-Score:-", f1_score(y_train, y_train_pred))
# Out:
# Accuracy:- 0.9993548245517786
# Precision:- 1.0
# Recall:- 1.0
# F1-Score:- 0.7966804979253113

# %%
# classification_report
print(classification_report(y_train, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227449
#            1       0.88      0.73      0.80       396
#
#     accuracy                           1.00    227845
#    macro avg       0.94      0.86      0.90    227845
# weighted avg       1.00      1.00      1.00    227845

# %%
# Predicted probability
y_train_pred_proba = rfc_imb_model.predict_proba(X_train)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_train, y_train_pred_proba)
auc
# Out:
# 0.9806368902501441

# %%
# Plot the ROC curve
draw_roc(y_train, y_train_pred_proba)

# %% [markdown]
# <font size="3">**Predictions on the test set**</font>

# %%
# Predictions on the test set
y_test_pred = rfc_imb_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[56845    21]
#  [   35    61]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))

# F1 score
print("F1-Score:-", f1_score(y_train, y_train_pred))
# Out:
# Accuracy:- 0.9990168884519505
# Precision:- 0.7439024390243902
# Recall:- 0.6354166666666666
# F1-Score:- 0.7966804979253113

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56866
#            1       0.74      0.64      0.69        96
#
#     accuracy                           1.00     56962
#    macro avg       0.87      0.82      0.84     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
# Predicted probability
y_test_pred_proba = rfc_imb_model.predict_proba(X_test)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_test, y_test_pred_proba)
auc
# Out:
# 0.9540721278971617

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# <font size="4">**Model summary - Random Forest**</font>
#
# - <font size="4">**Train set**</font>
#
#     - <font size="3">Accuracy:- 0.999</font>
#
#     - <font size="3">Precision:- 1.0</font>
#
#     - <font size="3">Recall:- 1.0</font>
#
#     - <font size="3">F1-Score:- 0.807</font>
#
#     - <font size="3">ROC :- 0.97</font>
#
#
# - <font size="3">**Test set**</font>
#
#     - <font size="3">Accuracy:- 0.999</font>
#
#     - <font size="3">Precision:- 0.726</font>
#
#     - <font size="3">Recall:- 0.635</font>
#
#     - <font size="3">F1-Score:- 0.807</font>
#
#     - <font size="3">ROC :- 0.96</font>

# %% [markdown]
# <font size="5">**4. XGBoost**</font>

# %%
import sys
# !{sys.executable} -m pip install xgboost

# %%
# Importing XGBoost
from xgboost import XGBClassifier

# %% [markdown]
# <font size="4">**4a. Tuning hyperparameters**</font>

# %%
# hyperparameter tuning with XGBoost

# creating a KFold object 
folds = 3

# specify range of hyperparameters
param_grid = {'learning_rate': [0.2, 0.6], 
             'subsample': [0.3, 0.6, 0.9]}          


# specify model
xgb_model = XGBClassifier(max_depth=2, n_estimators=200)

# set up GridSearchCV()
model_cv = GridSearchCV(estimator = xgb_model, 
                        param_grid = param_grid, 
                        scoring= 'roc_auc', 
                        cv = folds, 
                        verbose = 1,
                        return_train_score=True)      

# fit the model
model_cv.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      gamma=None, gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_bin=None,
#                                      max_ca...one,
#                                      max_delta_step=None, max_depth=2,
#                                      max_leaves=None, min_child_weight=None,
# ...

# %%
# cv results
cv_results = pd.DataFrame(model_cv.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       5.825091      0.017946         0.049209        0.003747
# 1       8.573963      0.126604         0.046562        0.002079
# 2       9.325015      0.040437         0.047904        0.001234
# 3       5.814868      0.187567         0.048051        0.002561
# 4      10.119923      2.848476         0.047301        0.002101
# 5       8.908892      0.106865         0.048357        0.002175
#
#   param_learning_rate param_subsample  \
# 0                 0.2             0.3
# 1                 0.2             0.6
# 2                 0.2             0.9
# 3                 0.6             0.3
# 4                 0.6             0.6
# 5                 0.6             0.9
#
#                                      params  split0_test_score  \
# 0  {'learning_rate': 0.2, 'subsample': 0.3}           0.979854
# 1  {'learning_rate': 0.2, 'subsample': 0.6}           0.977143
# ...

# %%
# # plotting
plt.figure(figsize=(16,6))

param_grid = {'learning_rate': [0.2, 0.6], 
             'subsample': [0.3, 0.6, 0.9]} 


for n, subsample in enumerate(param_grid['subsample']):
    

    # subplot 1/n
    plt.subplot(1,len(param_grid['subsample']), n+1)
    df = cv_results[cv_results['param_subsample']==subsample]

    plt.plot(df["param_learning_rate"], df["mean_test_score"])
    plt.plot(df["param_learning_rate"], df["mean_train_score"])
    plt.xlabel('learning_rate')
    plt.ylabel('AUC')
    plt.title("subsample={0}".format(subsample))
    plt.ylim([0.60, 1])
    plt.legend(['test score', 'train score'], loc='lower left')
    plt.xscale('log')

# %%
model_cv.best_params_
# Out:
# {'learning_rate': 0.2, 'subsample': 0.3}

# %% [markdown]
# We see that the train score almost touches to 1. Among the hyperparameters, we can choose the best parameters as learning_rate : 0.2 and subsample: 0.3

# %% [markdown]
# <font size="4">**4b. XGBoost model with optimal hyperparameters**</font>

# %%
# chosen hyperparameters
# 'objective':'binary:logistic' outputs probability rather than label, which we need for calculating auc
params = {'learning_rate': 0.2,
          'max_depth': 2, 
          'n_estimators':200,
          'subsample':0.9,
         'objective':'binary:logistic'}

# fit model on training data
xgb_imb_model = XGBClassifier(params = params)
xgb_imb_model.fit(X_train, y_train)
# Out:
# [17:53:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/learner.cc:627:
# Parameters: { "params" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
# ...

# %% [markdown]
# <font size="3">**Predictions on the train set**</font>

# %%
# Predictions on the train set
y_train_pred = xgb_imb_model.predict(X_train)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_train, y_train_pred)
print(confusion)
# Out:
# [[227449      0]
#  [     0    396]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_train, y_train_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))

# F1 score
print("F1-Score:-", f1_score(y_train, y_train_pred))
# Out:
# Accuracy:- 1.0
# Precision:- 1.0
# Recall:- 1.0
# F1-Score:- 1.0

# %%
# classification_report
print(classification_report(y_train, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227449
#            1       1.00      1.00      1.00       396
#
#     accuracy                           1.00    227845
#    macro avg       1.00      1.00      1.00    227845
# weighted avg       1.00      1.00      1.00    227845

# %%
# Predicted probability
y_train_pred_proba_imb_xgb = xgb_imb_model.predict_proba(X_train)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_train, y_train_pred_proba_imb_xgb)
auc
# Out:
# 1.0

# %%
# Plot the ROC curve
draw_roc(y_train, y_train_pred_proba_imb_xgb)

# %% [markdown]
# <font size="3">**Predictions on the test set**</font>

# %%
# Predictions on the test set
y_test_pred = xgb_imb_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[56859     7]
#  [   24    72]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))

# F1 score
print("F1-Score:-", f1_score(y_test, y_test_pred))
# Out:
# Accuracy:- 0.9994557775359011
# Precision:- 0.9113924050632911
# Recall:- 0.75
# F1-Score:- 0.8228571428571428

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56866
#            1       0.91      0.75      0.82        96
#
#     accuracy                           1.00     56962
#    macro avg       0.96      0.87      0.91     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
# Predicted probability
y_test_pred_proba = xgb_imb_model.predict_proba(X_test)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_test, y_test_pred_proba)
auc
# Out:
# 0.9785370798602563

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# <font size="4">**Model summary - XGBoost**</font>
#
# - <font size="4">**Train set**</font>
#
#     - <font size="3">Accuracy:- 1.0</font>
#
#     - <font size="3">Precision:- 1.0</font>
#
#     - <font size="3">Recall:- 1.0</font>
#
#     - <font size="3">F1-Score:- 1.0</font>
#
#     - <font size="3">ROC :- 1.0</font>
#
#
# - <font size="3">**Test set**</font>
#
#     - <font size="3">Accuracy:- 0.999</font>
#
#     - <font size="3">Precision:- 0.818</font>
#
#     - <font size="3">Recall:- 0.75</font>
#
#     - <font size="3">F1-Score:- 0.783</font>
#
#     - <font size="3">ROC :- 0.96</font>

# %% [markdown]
# <font size="4">**Choosing best model on the imbalanced data**</font>
#
# <font size="3">We can see that among all the models we tried (Logistic, Decision Tree, Random Forest, and XGBoost), almost all of them have performed well. More specifically Logistic regression and XGBoost performed best in terms of ROC-AUC score.</font>
#
# <font size="3">However, XGBoost requires more resource utilization than Logistic Regression and thus, building XGBoost model is costlier than Logistic Regression. Hence, we will choose Logistic Regression as the best model, which gives us ROC score of 0.99 on the train data and 0.97 on the test data.</font>
#
# <font size="3">The test data ROC score is 0.01 more than the test data ROC score in XGBoost model. The 0.01 increase of score may convert into huge amount of savings for the bank.</font>

# %% [markdown]
# <font size="4">**Print important features of the best model to understand the dataset**</font>
#  - <font size="3">This will not give much explanation on the already transformed dataset.</font>
#  - <font size="3">But it will help us in understanding if the dataset is not PCA transformed.</font>

# %%
# Features of Logistic Regression
importance = logistic_imb_model.coef_[0]

# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
    
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# Feature: 0, Score: -0.08798
# Feature: 1, Score: -0.06846
# Feature: 2, Score: -0.29581
# Feature: 3, Score: 0.57540
# Feature: 4, Score: 0.03295
# Feature: 5, Score: 0.01866
# Feature: 6, Score: -0.07447
# Feature: 7, Score: -0.20976
# Feature: 8, Score: -0.19377
# Feature: 9, Score: -0.19998
# Feature: 10, Score: 0.16166
# Feature: 11, Score: -0.50269
# Feature: 12, Score: -0.13717
# Feature: 13, Score: -0.69052
# Feature: 14, Score: -0.08208
# Feature: 15, Score: -0.18627
# Feature: 16, Score: -0.07793
# Feature: 17, Score: 0.04124
# Feature: 18, Score: -0.04059
# Feature: 19, Score: -0.02389
# Feature: 20, Score: 0.10862
# Feature: 21, Score: 0.11215
# Feature: 22, Score: -0.03558
# Feature: 23, Score: -0.02689
# Feature: 24, Score: 0.01321
# Feature: 25, Score: 0.00592
# Feature: 26, Score: -0.04420
# Feature: 27, Score: -0.02341
# Feature: 28, Score: 0.07492

# %% [markdown]
# <font size="4">*This is a classification problem with classes 0 and 1 and the coefficients are both positive and negative. The positive scores indicate a feature that predicts class 1, whereas the negative scores indicate a feature that predicts class 0.*</font>
#
# <font size="4">**No clear pattern of important and unimportant features can be identified from these results.**</font>

# %% [markdown]
# <font size="5">**Handling data imbalance**</font>
#
# <font size="3">As we see that the data is heavily imbalanced, We will try several approaches for handling data imbalance.</font>
#
#  - <font size="3">Undersampling :- Here for balancing the class distribution, the non-fraudulent transctions count will be reduced to 396 (similar count of fraudulent transctions)</font>
#  - <font size="3">Oversampling :- Here we will make the same count of non-fraudulent transctions as fraudulent transctions.</font>
#  - <font size="3">SMOTE :- Synthetic minority oversampling technique. It is another oversampling technique, which uses nearest neighbor algorithm to create synthetic data.</font>

# %% [markdown]
# <font size="5">**Undersampling**</font>

# %%
pip install imblearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing undersampler library
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter

# %%
# instantiating the random undersampler 
rus = RandomUnderSampler()
# resampling X, y
X_train_rus, y_train_rus = rus.fit_resample(X_train, y_train)

# %%
# Befor sampling class distribution
print('Before sampling class distribution:-',Counter(y_train))
# new class distribution 
print('New class distribution:-',Counter(y_train_rus))
# Out:
# Before sampling class distribution:- Counter({0: 227449, 1: 396})
# New class distribution:- Counter({0: 396, 1: 396})

# %% [markdown]
# <font size="4">**Model building on balanced data with Undersampling**</font>

# %% [markdown]
# <font size="4" >**1. Logistic Regression**</font>

# %% [markdown]
# <font size="4">**1a. Tuning hyperparameter C**</font>

# %%
# Creating KFold object with 5 splits
folds = KFold(n_splits=5, shuffle=True, random_state=4)

# Specify params
params = {"C": [0.01, 0.1, 1, 10, 100, 1000]}

# Specifing score as roc-auc
model_cv = GridSearchCV(estimator = LogisticRegression(),
                        param_grid = params, 
                        scoring= 'roc_auc', 
                        cv = folds, 
                        verbose = 1,
                        return_train_score=True) 

# Fit the model
model_cv.fit(X_train_rus, y_train_rus)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=4, shuffle=True),
#              estimator=LogisticRegression(),
#              param_grid={'C': [0.01, 0.1, 1, 10, 100, 1000]},
#              return_train_score=True, scoring='roc_auc', verbose=1)

# %%
# results of grid search CV
cv_results = pd.DataFrame(model_cv.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.006190      0.002097         0.001253        0.000164    0.01
# 1       0.010218      0.002178         0.001831        0.000458     0.1
# 2       0.010516      0.001644         0.001362        0.000485       1
# 3       0.014558      0.002306         0.001107        0.000106      10
# 4       0.016704      0.001794         0.001276        0.000473     100
# 5       0.021965      0.003681         0.001082        0.000044    1000
#
#         params  split0_test_score  split1_test_score  split2_test_score  \
# 0  {'C': 0.01}           0.987281           0.993511           0.974038
# 1   {'C': 0.1}           0.985692           0.991928           0.975000
# 2     {'C': 1}           0.982989           0.989079           0.972436
# 3    {'C': 10}           0.977424           0.988287           0.970192
# 4   {'C': 100}           0.975199           0.988762           0.968750
# ...

# %%
# plot of C versus train and validation scores

plt.figure(figsize=(8, 6))
plt.plot(cv_results['param_C'], cv_results['mean_test_score'])
plt.plot(cv_results['param_C'], cv_results['mean_train_score'])
plt.xlabel('C')
plt.ylabel('roc_auc')
plt.legend(['test result', 'train result'], loc='upper left')
plt.xscale('log')

# %%
# Best score with best C
best_score = model_cv.best_score_
best_C = model_cv.best_params_['C']

print(" The highest test roc_auc is {0} at C = {1}".format(best_score, best_C))
# Out:
#  The highest test roc_auc is 0.9837993434947057 at C = 0.01

# %% [markdown]
# <font size="4">**1b. Logistic regression with optimal C**</font>

# %%
# Instantiate the model with best C
logistic_bal_rus = LogisticRegression(C=0.1)

# %%
# Fit the model on the train set
logistic_bal_rus_model = logistic_bal_rus.fit(X_train_rus, y_train_rus)

# %% [markdown]
# <font size="3">**Predictions on the train set**</font>

# %%
# Predictions on the train set
y_train_pred = logistic_bal_rus_model.predict(X_train_rus)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_train_rus, y_train_pred)
print(confusion)
# Out:
# [[392   4]
#  [ 32 364]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_train_rus, y_train_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))

# F1 score
print("F1-Score:-", f1_score(y_train_rus, y_train_pred))
# Out:
# Accuracy:- 0.9545454545454546
# Precision:- 0.9891304347826086
# Recall:- 0.9191919191919192
# F1-Score:- 0.9528795811518325

# %%
# classification_report
print(classification_report(y_train_rus, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96       396
#            1       0.99      0.92      0.95       396
#
#     accuracy                           0.95       792
#    macro avg       0.96      0.95      0.95       792
# weighted avg       0.96      0.95      0.95       792

# %%
# Predicted probability
y_train_pred_proba = logistic_bal_rus_model.predict_proba(X_train_rus)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_train_rus, y_train_pred_proba)
auc
# Out:
# 0.9893059381695745

# %%
# Plot the ROC curve
draw_roc(y_train_rus, y_train_pred_proba)

# %% [markdown]
# <font size="3">**Predictions on the test set**</font>

# %%
# Prediction on the test set
y_test_pred = logistic_bal_rus_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[55565  1301]
#  [   13    83]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))
# Out:
# Accuracy:- 0.976931989747551
# Precision:- 0.05997109826589595
# Recall:- 0.8645833333333334

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56866
#            1       0.06      0.86      0.11        96
#
#     accuracy                           0.98     56962
#    macro avg       0.53      0.92      0.55     56962
# weighted avg       1.00      0.98      0.99     56962

# %%
# Predicted probability
y_test_pred_proba = logistic_bal_rus_model.predict_proba(X_test)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_test, y_test_pred_proba)
auc
# Out:
# 0.9600480735413077

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# <font size="4">**Model summary - Logistic Regression with Undersampling**</font>
#
# - <font size="4">**Train set**</font>
#
#     - <font size="3">Accuracy:- 0.951</font>
#
#     - <font size="3">Precision:- 0.984</font>
#
#     - <font size="3">Recall:- 0.917</font>
#
#     - <font size="3">ROC :- 0.99</font>
#
#
# - <font size="3">**Test set**</font>
#
#     - <font size="3">Accuracy:- 0.978</font>
#
#     - <font size="3">Precision:- 0.062</font>
#
#     - <font size="3">Recall:- 0.875</font>
#
#     - <font size="3">ROC :- 0.96</font>

# %% [markdown]
# <font size="4" >**2. XGBoost**</font>

# %% [markdown]
# <font size="4">**2a. Tuning hyperparameters**</font>

# %%
# hyperparameter tuning with XGBoost

# creating a KFold object 
folds = 3

# specify range of hyperparameters
param_grid = {'learning_rate': [0.2, 0.6], 
             'subsample': [0.3, 0.6, 0.9]}          


# specify model
xgb_model = XGBClassifier(max_depth=2, n_estimators=200)

# set up GridSearchCV()
model_cv = GridSearchCV(estimator = xgb_model, 
                        param_grid = param_grid, 
                        scoring= 'roc_auc', 
                        cv = folds, 
                        verbose = 1,
                        return_train_score=True)      

# fit the model
model_cv.fit(X_train_rus, y_train_rus)
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      gamma=None, gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_bin=None,
#                                      max_ca...one,
#                                      max_delta_step=None, max_depth=2,
#                                      max_leaves=None, min_child_weight=None,
# ...

# %%
# cv results
cv_results = pd.DataFrame(model_cv.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.185308      0.024866         0.002482        0.000110
# 1       0.204996      0.005734         0.003049        0.000620
# 2       0.213818      0.012921         0.002492        0.000205
# 3       0.157623      0.010103         0.002592        0.000298
# 4       0.180217      0.005293         0.002631        0.000157
# 5       0.185937      0.010662         0.002707        0.000479
#
#   param_learning_rate param_subsample  \
# 0                 0.2             0.3
# 1                 0.2             0.6
# 2                 0.2             0.9
# 3                 0.6             0.3
# 4                 0.6             0.6
# 5                 0.6             0.9
#
#                                      params  split0_test_score  \
# 0  {'learning_rate': 0.2, 'subsample': 0.3}           0.957530
# 1  {'learning_rate': 0.2, 'subsample': 0.6}           0.963326
# ...

# %%
# # plotting
plt.figure(figsize=(16,6))

param_grid = {'learning_rate': [0.2, 0.6], 
             'subsample': [0.3, 0.6, 0.9]} 


for n, subsample in enumerate(param_grid['subsample']):
    

    # subplot 1/n
    plt.subplot(1,len(param_grid['subsample']), n+1)
    df = cv_results[cv_results['param_subsample']==subsample]

    plt.plot(df["param_learning_rate"], df["mean_test_score"])
    plt.plot(df["param_learning_rate"], df["mean_train_score"])
    plt.xlabel('learning_rate')
    plt.ylabel('AUC')
    plt.title("subsample={0}".format(subsample))
    plt.ylim([0.60, 1])
    plt.legend(['test score', 'train score'], loc='upper left')
    plt.xscale('log')

# %%
model_cv.best_params_
# Out:
# {'learning_rate': 0.2, 'subsample': 0.9}

# %% [markdown]
# We see that the train score almost touches to 1. Among the hyperparameters, we can choose the best parameters as learning_rate : 0.2 and subsample: 0.6.

# %% [markdown]
# <font size="4">**2b. XGBoost model with optimal hyperparameters**</font>

# %%
# chosen hyperparameters
# 'objective':'binary:logistic' outputs probability rather than label, which we need for calculating auc
params = {'learning_rate': 0.2,
          'max_depth': 2, 
          'n_estimators':200,
          'subsample':0.6,
         'objective':'binary:logistic'}

# fit model on training data
xgb_bal_rus_model = XGBClassifier(params = params)
xgb_bal_rus_model.fit(X_train_rus, y_train_rus)
# Out:
# [17:54:17] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/learner.cc:627:
# Parameters: { "params" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
# ...

# %% [markdown]
# <font size="3">**Predictions on the train set**</font>

# %%
# Predictions on the train set
y_train_pred = xgb_bal_rus_model.predict(X_train_rus)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_train_rus, y_train_rus)
print(confusion)
# Out:
# [[396   0]
#  [  0 396]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_train_rus, y_train_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))
# Out:
# Accuracy:- 1.0
# Precision:- 1.0
# Recall:- 1.0

# %%
# classification_report
print(classification_report(y_train_rus, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       396
#            1       1.00      1.00      1.00       396
#
#     accuracy                           1.00       792
#    macro avg       1.00      1.00      1.00       792
# weighted avg       1.00      1.00      1.00       792

# %%
# Predicted probability
y_train_pred_proba = xgb_bal_rus_model.predict_proba(X_train_rus)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_train_rus, y_train_pred_proba)
auc
# Out:
# 1.0

# %%
# Plot the ROC curve
draw_roc(y_train_rus, y_train_pred_proba)

# %% [markdown]
# <font size="3">**Predictions on the test set**</font>

# %%
# Predictions on the test set
y_test_pred = xgb_bal_rus_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[54837  2029]
#  [   10    86]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))
# Out:
# Accuracy:- 0.9642042063129805
# Precision:- 0.04066193853427896
# Recall:- 0.8958333333333334

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     56866
#            1       0.04      0.90      0.08        96
#
#     accuracy                           0.96     56962
#    macro avg       0.52      0.93      0.53     56962
# weighted avg       1.00      0.96      0.98     56962

# %%
# Predicted probability
y_test_pred_proba = xgb_bal_rus_model.predict_proba(X_test)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_test, y_test_pred_proba)
auc
# Out:
# 0.9759258607955544

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# <font size="4">**Model summary - XGBoost with Undersampling**</font>
#
# - <font size="4">**Train set**</font>
#
#     - <font size="3">Accuracy:- 1.0</font>
#
#     - <font size="3">Precision:- 1.0</font>
#
#     - <font size="3">Recall:- 1.0</font>
#
#     - <font size="3">ROC :- 1.0</font>
#
#
# - <font size="3">**Test set**</font>
#
#     - <font size="3">Accuracy:- 0.960</font>
#
#     - <font size="3">Precision:- 0.037</font>
#
#     - <font size="3">Recall:- 0.906</font>
#
#     - <font size="3">ROC :- 0.98</font>

# %% [markdown]
# <font size="4" >**3. Decision Tree**</font>

# %% [markdown]
# <font size="4">**3a. Tuning hyperparameters**</font>

# %%
# Create the parameter grid 
param_grid = {
    'max_depth': range(5, 15, 5),
    'min_samples_leaf': range(50, 150, 50),
    'min_samples_split': range(50, 150, 50),
}


# Instantiate the grid search model
dtree = DecisionTreeClassifier()

grid_search = GridSearchCV(estimator = dtree, 
                           param_grid = param_grid, 
                           scoring= 'roc_auc',
                           cv = 3, 
                           verbose = 1)

# Fit the grid search to the data
grid_search.fit(X_train_rus,y_train_rus)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': range(5, 15, 5),
#                          'min_samples_leaf': range(50, 150, 50),
#                          'min_samples_split': range(50, 150, 50)},
#              scoring='roc_auc', verbose=1)

# %%
# cv results
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.003865      0.000318         0.001464        0.000234
# 1       0.003772      0.000096         0.001417        0.000149
# 2       0.002602      0.000020         0.001140        0.000084
# 3       0.002531      0.000039         0.001037        0.000006
# 4       0.003328      0.000052         0.001042        0.000015
# 5       0.003353      0.000018         0.001086        0.000069
# 6       0.002609      0.000147         0.001104        0.000075
# 7       0.002599      0.000078         0.001216        0.000150
#
#   param_max_depth param_min_samples_leaf param_min_samples_split  \
# 0               5                     50                      50
# 1               5                     50                     100
# 2               5                    100                      50
# 3               5                    100                     100
# ...

# %%
# Printing the optimal sensitivity score and hyperparameters
print("Best roc_auc:-", grid_search.best_score_)
print(grid_search.best_estimator_)
# Out:
# Best roc_auc:- 0.9615759871441689
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=50, min_samples_split=50)

# %% [markdown]
# <font size="4">**3b. Decision Tree with optimal hyperparameters**</font>

# %%
# Model with optimal hyperparameters
dt_bal_rus_model = DecisionTreeClassifier(criterion = "gini", 
                                  random_state = 100,
                                  max_depth=5, 
                                  min_samples_leaf=50,
                                  min_samples_split=50)

dt_bal_rus_model.fit(X_train_rus, y_train_rus)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=50, min_samples_split=50,
#                        random_state=100)

# %% [markdown]
# <font size="3">**Predictions on the train set**</font>

# %%
# Predictions on the train set
y_train_pred = dt_bal_rus_model.predict(X_train_rus)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_train_rus, y_train_pred)
print(confusion)
# Out:
# [[390   6]
#  [ 52 344]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_train_rus, y_train_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))
# Out:
# Accuracy:- 0.9267676767676768
# Precision:- 0.9828571428571429
# Recall:- 0.8686868686868687

# %%
# classification_report
print(classification_report(y_train_rus, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       396
#            1       0.98      0.87      0.92       396
#
#     accuracy                           0.93       792
#    macro avg       0.93      0.93      0.93       792
# weighted avg       0.93      0.93      0.93       792

# %%
# Predicted probability
y_train_pred_proba = dt_bal_rus_model.predict_proba(X_train_rus)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_train_rus, y_train_pred_proba)
auc
# Out:
# 0.9786373839404142

# %%
# Plot the ROC curve
draw_roc(y_train_rus, y_train_pred_proba)

# %% [markdown]
# <font size="3">**Predictions on the test set**</font>

# %%
# Predictions on the test set
y_test_pred = dt_bal_rus_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[55703  1163]
#  [   19    77]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))
# Out:
# Accuracy:- 0.9792493241108107
# Precision:- 0.062096774193548386
# Recall:- 0.8020833333333334

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56866
#            1       0.06      0.80      0.12        96
#
#     accuracy                           0.98     56962
#    macro avg       0.53      0.89      0.55     56962
# weighted avg       1.00      0.98      0.99     56962

# %%
# Predicted probability
y_test_pred_proba = dt_bal_rus_model.predict_proba(X_test)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_test, y_test_pred_proba)
auc
# Out:
# 0.965019464618577

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# <font size="4">**Model summary - Decision Tree with Undersampling**</font>
#
# - <font size="4">**Train set**</font>
#
#     - <font size="3">Accuracy:- 0.924</font>
#
#     - <font size="3">Precision:- 0.98</font>
#
#     - <font size="3">Recall:- 0.866</font>
#
#     - <font size="3">ROC :- 0.98</font>
#
#
# - <font size="3">**Test set**</font>
#
#     - <font size="3">Accuracy:- 0.981</font>
#
#     - <font size="3">Precision:- 0.068</font>
#
#     - <font size="3">Recall:- 0.802</font>
#
#     - <font size="3">ROC :- 0.97</font>

# %% [markdown]
# <font size="4" >**4. Random Forest**</font>

# %% [markdown]
# <font size="4">**4a. Tuning hyperparameters**</font>

# %%
param_grid = {
    'max_depth': range(5,10,5),
    'min_samples_leaf': range(50, 150, 50),
    'min_samples_split': range(50, 150, 50),
    'n_estimators': [100,200,300], 
    'max_features': [10, 20]
}
# Create a based model
rf = RandomForestClassifier()
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rf, 
                           param_grid = param_grid, 
                           scoring= 'roc_auc',
                           cv = 2,
                           n_jobs = -1,
                           verbose = 1, 
                           return_train_score=True)

# Fit the model
grid_search.fit(X_train_rus, y_train_rus)
# Out:
# Fitting 2 folds for each of 24 candidates, totalling 48 fits
# GridSearchCV(cv=2, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': range(5, 10, 5), 'max_features': [10, 20],
#                          'min_samples_leaf': range(50, 150, 50),
#                          'min_samples_split': range(50, 150, 50),
#                          'n_estimators': [100, 200, 300]},
#              return_train_score=True, scoring='roc_auc', verbose=1)

# %%
# printing the optimal accuracy score and hyperparameters
print('We can get roc-auc of',grid_search.best_score_,'using',grid_search.best_params_)
# Out:
# We can get roc-auc of 0.9752384960718294 using {'max_depth': 5, 'max_features': 20, 'min_samples_leaf': 50, 'min_samples_split': 100, 'n_estimators': 100}

# %% [markdown]
# <font size="4">**4b. Random Forest with optimal hyperparameters**</font>

# %%
# model with the best hyperparameters

rfc_bal_rus_model = RandomForestClassifier(bootstrap=True,
                             max_depth=5,
                             min_samples_leaf=50, 
                             min_samples_split=50,
                             max_features=10,
                             n_estimators=200)

# %%
# Fit the model
rfc_bal_rus_model.fit(X_train_rus, y_train_rus)
# Out:
# RandomForestClassifier(max_depth=5, max_features=10, min_samples_leaf=50,
#                        min_samples_split=50, n_estimators=200)

# %% [markdown]
# <font size="3">**Predictions on the train set**</font>

# %%
# Predictions on the train set
y_train_pred = rfc_bal_rus_model.predict(X_train_rus)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_train_rus, y_train_pred)
print(confusion)
# Out:
# [[391   5]
#  [ 43 353]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_train_rus, y_train_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))

# F1 score
print("F1-Score:-", f1_score(y_train_rus, y_train_pred))
# Out:
# Accuracy:- 0.9393939393939394
# Precision:- 0.9860335195530726
# Recall:- 0.8914141414141414
# F1-Score:- 0.9363395225464192

# %%
# classification_report
print(classification_report(y_train_rus, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94       396
#            1       0.99      0.89      0.94       396
#
#     accuracy                           0.94       792
#    macro avg       0.94      0.94      0.94       792
# weighted avg       0.94      0.94      0.94       792

# %%
# Predicted probability
y_train_pred_proba = rfc_bal_rus_model.predict_proba(X_train_rus)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_train_rus, y_train_pred_proba)
auc
# Out:
# 0.9857221201918172

# %%
# Plot the ROC curve
draw_roc(y_train_rus, y_train_pred_proba)

# %% [markdown]
# <font size="3">**Predictions on the test set**</font>

# %%
# Predictions on the test set
y_test_pred = rfc_bal_rus_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[55751  1115]
#  [   18    78]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))
# Out:
# Accuracy:- 0.9801095467153541
# Precision:- 0.06538139145012574
# Recall:- 0.8125

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56866
#            1       0.07      0.81      0.12        96
#
#     accuracy                           0.98     56962
#    macro avg       0.53      0.90      0.56     56962
# weighted avg       1.00      0.98      0.99     56962

# %%
# Predicted probability
y_test_pred_proba = rfc_bal_rus_model.predict_proba(X_test)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_test, y_test_pred_proba)
auc
# Out:
# 0.9713451908873492

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# <font size="4">**Model summary - Random Forest with Undersampling**</font>
#
# - <font size="4">**Train set**</font>
#
#     - <font size="3">Accuracy:- 0.939</font>
#
#     - <font size="3">Precision:- 0.986</font>
#
#     - <font size="3">Recall:- 0.891</font>
#
#     - <font size="3">ROC :- 0.98</font>
#
#
# - <font size="3">**Test set**</font>
#
#     - <font size="3">Accuracy:- 0.988</font>
#
#     - <font size="3">Precision:- 0.106</font>
#
#     - <font size="3">Recall:- 0.823</font>
#
#     - <font size="3">ROC :- 0.97</font>

# %% [markdown]
# <font size="5">**Oversampling**</font>

# %%
# Importing oversampler library
from imblearn.over_sampling import RandomOverSampler

# %%
# instantiating the random oversampler 
ros = RandomOverSampler()
# resampling X, y
X_train_ros, y_train_ros = ros.fit_resample(X_train, y_train)

# %%
# Befor sampling class distribution
print('Before sampling class distribution:-',Counter(y_train))
# new class distribution 
print('New class distribution:-',Counter(y_train_ros))
# Out:
# Before sampling class distribution:- Counter({0: 227449, 1: 396})
# New class distribution:- Counter({0: 227449, 1: 227449})

# %% [markdown]
# <font size="4">**Model building on balanced data with Oversampling**</font>

# %% [markdown]
# <font size="4" >**1. Logistic Regression**</font>

# %% [markdown]
# <font size="4">**1a. Tuning hyperparameter C**</font>

# %%
# Creating KFold object with 5 splits
folds = KFold(n_splits=5, shuffle=True, random_state=4)

# Specify params
params = {"C": [0.01, 0.1, 1, 10, 100, 1000]}

# Specifing score as roc-auc
model_cv = GridSearchCV(estimator = LogisticRegression(),
                        param_grid = params, 
                        scoring= 'roc_auc', 
                        cv = folds, 
                        verbose = 1,
                        return_train_score=True) 

# Fit the model
model_cv.fit(X_train_ros, y_train_ros)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=4, shuffle=True),
#              estimator=LogisticRegression(),
#              param_grid={'C': [0.01, 0.1, 1, 10, 100, 1000]},
#              return_train_score=True, scoring='roc_auc', verbose=1)

# %%
# results of grid search CV
cv_results = pd.DataFrame(model_cv.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.432151      0.047903         0.018565        0.000660    0.01
# 1       0.409822      0.013166         0.018358        0.000455     0.1
# 2       0.418885      0.025606         0.018152        0.000303       1
# 3       0.397294      0.024110         0.019480        0.002470      10
# 4       0.392567      0.021705         0.017992        0.000098     100
# 5       0.417845      0.016391         0.018408        0.000538    1000
#
#         params  split0_test_score  split1_test_score  split2_test_score  \
# 0  {'C': 0.01}           0.988408           0.988200           0.988665
# 1   {'C': 0.1}           0.988430           0.988210           0.988679
# 2     {'C': 1}           0.988428           0.988211           0.988680
# 3    {'C': 10}           0.988427           0.988211           0.988680
# 4   {'C': 100}           0.988427           0.988211           0.988680
# ...

# %%
# plot of C versus train and validation scores

plt.figure(figsize=(8, 6))
plt.plot(cv_results['param_C'], cv_results['mean_test_score'])
plt.plot(cv_results['param_C'], cv_results['mean_train_score'])
plt.xlabel('C')
plt.ylabel('roc_auc')
plt.legend(['test result', 'train result'], loc='upper left')
plt.xscale('log')

# %%
# Best score with best C
best_score = model_cv.best_score_
best_C = model_cv.best_params_['C']

print(" The highest test roc_auc is {0} at C = {1}".format(best_score, best_C))
# Out:
#  The highest test roc_auc is 0.9884942584508789 at C = 0.1

# %% [markdown]
# <font size="4">**1b. Logistic regression with optimal C**</font>

# %%
# Instantiate the model with best C
logistic_bal_ros = LogisticRegression(C=0.1)

# %%
# Fit the model on the train set
logistic_bal_ros_model = logistic_bal_ros.fit(X_train_ros, y_train_ros)

# %% [markdown]
# <font size="3">**Predictions on the train set**</font>

# %%
# Predictions on the train set
y_train_pred = logistic_bal_ros_model.predict(X_train_ros)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_train_ros, y_train_pred)
print(confusion)
# Out:
# [[222239   5210]
#  [ 17839 209610]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_train_ros, y_train_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))

# F1 score
print("F1-Score:-", f1_score(y_train_ros, y_train_pred))
# Out:
# Accuracy:- 0.9493314984897714
# Precision:- 0.975747137138069
# Recall:- 0.9215692309045105
# F1-Score:- 0.9478846584318593

# %%
# classification_report
print(classification_report(y_train_ros, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95    227449
#            1       0.98      0.92      0.95    227449
#
#     accuracy                           0.95    454898
#    macro avg       0.95      0.95      0.95    454898
# weighted avg       0.95      0.95      0.95    454898

# %%
# Predicted probability
y_train_pred_proba = logistic_bal_ros_model.predict_proba(X_train_ros)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_train_ros, y_train_pred_proba)
auc
# Out:
# 0.9885073490047296

# %%
# Plot the ROC curve
draw_roc(y_train_ros, y_train_pred_proba)

# %% [markdown]
# <font size="3">**Predictions on the test set**</font>

# %%
# Prediction on the test set
y_test_pred = logistic_bal_ros_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[55529  1337]
#  [   11    85]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))
# Out:
# Accuracy:- 0.976335100593378
# Precision:- 0.05977496483825598
# Recall:- 0.8854166666666666

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56866
#            1       0.06      0.89      0.11        96
#
#     accuracy                           0.98     56962
#    macro avg       0.53      0.93      0.55     56962
# weighted avg       1.00      0.98      0.99     56962

# %%
# Predicted probability
y_test_pred_proba = logistic_bal_ros_model.predict_proba(X_test)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_test, y_test_pred_proba)
auc
# Out:
# 0.9712617527755306

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# <font size="4">**Model summary - Logistic Regression with Oversampling**</font>
#
# - <font size="4">**Train set**</font>
#
#     - <font size="3">Accuracy:- 0.951</font>
#
#     - <font size="3">Precision:- 0.976</font>
#
#     - <font size="3">Recall:- 0.924</font>
#
#     - <font size="3">ROC :- 0.99</font>
#
#
# - <font size="3">**Test set**</font>
#
#     - <font size="3">Accuracy:- 0.976</font>
#
#     - <font size="3">Precision:- 0.059</font>
#
#     - <font size="3">Recall:- 0.885</font>
#
#     - <font size="3">ROC :- 0.97</font>

# %% [markdown]
# <font size="4" >**2. XGBoost**</font>

# %% [markdown]
# <font size="4">**2a. Tuning hyperparameters**</font>

# %%
# hyperparameter tuning with XGBoost

# creating a KFold object 
folds = 3

# specify range of hyperparameters
param_grid = {'learning_rate': [0.2, 0.6], 
             'subsample': [0.3, 0.6, 0.9]}          


# specify model
xgb_model = XGBClassifier(max_depth=2, n_estimators=200)

# set up GridSearchCV()
model_cv = GridSearchCV(estimator = xgb_model, 
                        param_grid = param_grid, 
                        scoring= 'roc_auc', 
                        cv = folds, 
                        verbose = 1,
                        return_train_score=True)      

# fit the model
model_cv.fit(X_train_ros, y_train_ros)
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      gamma=None, gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_bin=None,
#                                      max_ca...one,
#                                      max_delta_step=None, max_depth=2,
#                                      max_leaves=None, min_child_weight=None,
# ...

# %%
# cv results
cv_results = pd.DataFrame(model_cv.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      10.123524      0.168475         0.093657        0.001972
# 1      12.926920      0.282525         0.080839        0.001903
# 2      12.823992      0.105373         0.080331        0.000876
# 3       9.900637      0.141928         0.081367        0.003317
# 4      12.807702      0.119584         0.078701        0.001285
# 5      12.912693      0.141092         0.087849        0.008868
#
#   param_learning_rate param_subsample  \
# 0                 0.2             0.3
# 1                 0.2             0.6
# 2                 0.2             0.9
# 3                 0.6             0.3
# 4                 0.6             0.6
# 5                 0.6             0.9
#
#                                      params  split0_test_score  \
# 0  {'learning_rate': 0.2, 'subsample': 0.3}           0.999920
# 1  {'learning_rate': 0.2, 'subsample': 0.6}           0.999898
# ...

# %%
# # plotting
plt.figure(figsize=(16,6))

param_grid = {'learning_rate': [0.2, 0.6], 
             'subsample': [0.3, 0.6, 0.9]} 


for n, subsample in enumerate(param_grid['subsample']):
    

    # subplot 1/n
    plt.subplot(1,len(param_grid['subsample']), n+1)
    df = cv_results[cv_results['param_subsample']==subsample]

    plt.plot(df["param_learning_rate"], df["mean_test_score"])
    plt.plot(df["param_learning_rate"], df["mean_train_score"])
    plt.xlabel('learning_rate')
    plt.ylabel('AUC')
    plt.title("subsample={0}".format(subsample))
    plt.ylim([0.60, 1])
    plt.legend(['test score', 'train score'], loc='upper left')
    plt.xscale('log')

# %%
model_cv.best_params_
# Out:
# {'learning_rate': 0.6, 'subsample': 0.6}

# %% [markdown]
# We see that the train score almost touches to 1. Among the hyperparameters, we can choose the best parameters as learning_rate : 0.6 and subsample: 0.3.

# %% [markdown]
# <font size="4">**2b. XGBoost model with optimal hyperparameters**</font>

# %%
# chosen hyperparameters
params = {'learning_rate': 0.6,
          'max_depth': 2, 
          'n_estimators':200,
          'subsample':0.9,
         'objective':'binary:logistic'}

# fit model on training data
xgb_bal_ros_model = XGBClassifier(params = params)
xgb_bal_ros_model.fit(X_train_ros, y_train_ros)
# Out:
# [17:58:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/learner.cc:627:
# Parameters: { "params" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
# ...

# %% [markdown]
# <font size="3">**Predictions on the train set**</font>

# %%
# Predictions on the train set
y_train_pred = xgb_bal_ros_model.predict(X_train_ros)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_train_ros, y_train_ros)
print(confusion)
# Out:
# [[227449      0]
#  [     0 227449]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_train_ros, y_train_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))
# Out:
# Accuracy:- 1.0
# Precision:- 1.0
# Recall:- 1.0

# %%
# classification_report
print(classification_report(y_train_ros, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227449
#            1       1.00      1.00      1.00    227449
#
#     accuracy                           1.00    454898
#    macro avg       1.00      1.00      1.00    454898
# weighted avg       1.00      1.00      1.00    454898

# %%
# Predicted probability
y_train_pred_proba = xgb_bal_ros_model.predict_proba(X_train_ros)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_train_ros, y_train_pred_proba)
auc
# Out:
# 1.0

# %%
# Plot the ROC curve
draw_roc(y_train_ros, y_train_pred_proba)

# %% [markdown]
# <font size="3">**Predictions on the test set**</font>

# %%
# Predictions on the test set
y_test_pred = xgb_bal_ros_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[56855    11]
#  [   19    77]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))
# Out:
# Accuracy:- 0.9994733330992591
# Precision:- 0.875
# Recall:- 0.8020833333333334

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56866
#            1       0.88      0.80      0.84        96
#
#     accuracy                           1.00     56962
#    macro avg       0.94      0.90      0.92     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
# Predicted probability
y_test_pred_proba = xgb_bal_ros_model.predict_proba(X_test)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_test, y_test_pred_proba)
auc
# Out:
# 0.9774269225020222

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# <font size="4">**Model summary - XGBoost with Oversampling**</font>
#
# - <font size="4">**Train set**</font>
#
#     - <font size="3">Accuracy:- 1.0</font>
#
#     - <font size="3">Precision:- 1.0</font>
#
#     - <font size="3">Recall:- 1.0</font>
#
#     - <font size="3">ROC :- 1.0</font>
#
#
# - <font size="3">**Test set**</font>
#
#     - <font size="3">Accuracy:- 0.999</font>
#
#     - <font size="3">Precision:- 0.894</font>
#
#     - <font size="3">Recall:- 0.792</font>
#
#     - <font size="3">ROC :- 0.98</font>

# %% [markdown]
# <font size="4" >**3. Decision Tree**</font>

# %% [markdown]
# <font size="4">**3a. Tuning hyperparameters**</font>

# %%
# Create the parameter grid 
param_grid = {
    'max_depth': range(5, 15, 5),
    'min_samples_leaf': range(50, 150, 50),
    'min_samples_split': range(50, 150, 50),
}


# Instantiate the grid search model
dtree = DecisionTreeClassifier()

grid_search = GridSearchCV(estimator = dtree, 
                           param_grid = param_grid, 
                           scoring= 'roc_auc',
                           cv = 3, 
                           verbose = 1)

# Fit the grid search to the data
grid_search.fit(X_train_ros,y_train_ros)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': range(5, 15, 5),
#                          'min_samples_leaf': range(50, 150, 50),
#                          'min_samples_split': range(50, 150, 50)},
#              scoring='roc_auc', verbose=1)

# %%
# cv results
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       2.745459      0.036113         0.025207        0.000339
# 1       2.726033      0.019685         0.025133        0.000190
# 2       2.707498      0.005619         0.025263        0.000079
# 3       2.702353      0.012285         0.025270        0.000028
# 4       4.206164      0.003625         0.025038        0.000547
# 5       4.198511      0.016638         0.025591        0.000388
# 6       4.181038      0.035735         0.025601        0.001328
# 7       4.116793      0.022559         0.024798        0.000364
#
#   param_max_depth param_min_samples_leaf param_min_samples_split  \
# 0               5                     50                      50
# 1               5                     50                     100
# 2               5                    100                      50
# 3               5                    100                     100
# ...

# %%
# Printing the optimal sensitivity score and hyperparameters
print("Best roc_auc:-", grid_search.best_score_)
print(grid_search.best_estimator_)
# Out:
# Best roc_auc:- 0.9996236607168821
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=100,
#                        min_samples_split=100)

# %% [markdown]
# <font size="4">**3b. Decision Tree with optimal hyperparameters**</font>

# %%
# Model with optimal hyperparameters
dt_bal_ros_model = DecisionTreeClassifier(criterion = "gini", 
                                  random_state = 100,
                                  max_depth=10, 
                                  min_samples_leaf=100,
                                  min_samples_split=50)

dt_bal_ros_model.fit(X_train_ros, y_train_ros)
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=100, min_samples_split=50,
#                        random_state=100)

# %% [markdown]
# <font size="3">**Predictions on the train set**</font>

# %%
# Predictions on the train set
y_train_pred = dt_bal_ros_model.predict(X_train_ros)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_train_ros, y_train_pred)
print(confusion)
# Out:
# [[225799   1650]
#  [     0 227449]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_train_ros, y_train_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))
# Out:
# Accuracy:- 0.9963728132460463
# Precision:- 0.9927978734084392
# Recall:- 1.0

# %%
# classification_report
print(classification_report(y_train_ros, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    227449
#            1       0.99      1.00      1.00    227449
#
#     accuracy                           1.00    454898
#    macro avg       1.00      1.00      1.00    454898
# weighted avg       1.00      1.00      1.00    454898

# %%
# Predicted probability
y_train_pred_proba = dt_bal_ros_model.predict_proba(X_train_ros)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_train_ros, y_train_pred_proba)
auc
# Out:
# 0.9997540017824167

# %%
# Plot the ROC curve
draw_roc(y_train_ros, y_train_pred_proba)

# %% [markdown]
# <font size="3">**Predictions on the test set**</font>

# %%
# Predictions on the test set
y_test_pred = dt_bal_ros_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[56412   454]
#  [   21    75]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))
# Out:
# Accuracy:- 0.9916611074049366
# Precision:- 0.14177693761814744
# Recall:- 0.78125

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56866
#            1       0.14      0.78      0.24        96
#
#     accuracy                           0.99     56962
#    macro avg       0.57      0.89      0.62     56962
# weighted avg       1.00      0.99      0.99     56962

# %%
# Predicted probability
y_test_pred_proba = dt_bal_ros_model.predict_proba(X_test)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_test, y_test_pred_proba)
auc
# Out:
# 0.8896148584684462

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# <font size="4">**Model summary - Decision Tree with Oversampling**</font>
#
# - <font size="4">**Train set**</font>
#
#     - <font size="3">Accuracy:- 0.995</font>
#
#     - <font size="3">Precision:- 0.990</font>
#
#     - <font size="3">Recall:- 1.0</font>
#
#     - <font size="3">ROC :- 1.0</font>
#
#
# - <font size="3">**Test set**</font>
#
#     - <font size="3">Accuracy:- 0.989</font>
#
#     - <font size="3">Precision:- 0.109</font>
#
#     - <font size="3">Recall:- 0.781</font>
#
#     - <font size="3">ROC :- 0.89</font>

# %% [markdown]
# <font size="5">**SMOTE (Synthetic Minority Oversampling Technique)**</font>

# %% [markdown]
# <font size="3">We are creating synthetic samples by doing upsampling using SMOTE (Synthetic Minority Oversampling Technique).</font>

# %%
# Importing SMOTE
from imblearn.over_sampling import SMOTE

# %%
# Instantiate SMOTE
sm = SMOTE(random_state=27)
# Fitting SMOTE to the train set
X_train_smote, y_train_smote = sm.fit_resample(X_train, y_train)

# %%
print('Before SMOTE oversampling X_train shape=',X_train.shape)
print('After SMOTE oversampling X_train shape=',X_train_smote.shape)
# Out:
# Before SMOTE oversampling X_train shape= (227845, 29)
# After SMOTE oversampling X_train shape= (454898, 29)

# %% [markdown]
# <font size="4">**Model building on balanced data with SMOTE**</font>

# %% [markdown]
# <font size="4" >**1. Logistic Regression**</font>

# %% [markdown]
# <font size="4">**1a. Tuning hyperparameter C**</font>

# %%
# Creating KFold object with 5 splits
folds = KFold(n_splits=5, shuffle=True, random_state=4)

# Specify params
params = {"C": [0.01, 0.1, 1, 10, 100, 1000]}

# Specifing score as roc-auc
model_cv = GridSearchCV(estimator = LogisticRegression(),
                        param_grid = params, 
                        scoring= 'roc_auc', 
                        cv = folds, 
                        verbose = 1,
                        return_train_score=True) 

# Fit the model
model_cv.fit(X_train_smote, y_train_smote)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=4, shuffle=True),
#              estimator=LogisticRegression(),
#              param_grid={'C': [0.01, 0.1, 1, 10, 100, 1000]},
#              return_train_score=True, scoring='roc_auc', verbose=1)

# %%
# results of grid search CV
cv_results = pd.DataFrame(model_cv.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.368069      0.020510         0.019693        0.000297    0.01
# 1       0.366590      0.023225         0.020308        0.001377     0.1
# 2       0.376965      0.016960         0.019803        0.000292       1
# 3       0.379604      0.020937         0.020208        0.000448      10
# 4       0.381591      0.022566         0.019815        0.000578     100
# 5       0.382110      0.016795         0.019524        0.000058    1000
#
#         params  split0_test_score  split1_test_score  split2_test_score  \
# 0  {'C': 0.01}           0.989805           0.989796           0.989484
# 1   {'C': 0.1}           0.989834           0.989807           0.989488
# 2     {'C': 1}           0.989836           0.989807           0.989486
# 3    {'C': 10}           0.989836           0.989807           0.989486
# 4   {'C': 100}           0.989836           0.989807           0.989486
# ...

# %%
# plot of C versus train and validation scores

plt.figure(figsize=(8, 6))
plt.plot(cv_results['param_C'], cv_results['mean_test_score'])
plt.plot(cv_results['param_C'], cv_results['mean_train_score'])
plt.xlabel('C')
plt.ylabel('roc_auc')
plt.legend(['test result', 'train result'], loc='upper left')
plt.xscale('log')

# %%
# Best score with best C
best_score = model_cv.best_score_
best_C = model_cv.best_params_['C']

print(" The highest test roc_auc is {0} at C = {1}".format(best_score, best_C))
# Out:
#  The highest test roc_auc is 0.9897409900830768 at C = 0.1

# %% [markdown]
# <font size="4">**1b. Logistic regression with optimal C**</font>

# %%
# Instantiate the model with best C
logistic_bal_smote = LogisticRegression(C=0.1)

# %%
# Fit the model on the train set
logistic_bal_smote_model = logistic_bal_smote.fit(X_train_smote, y_train_smote)

# %% [markdown]
# <font size="3">**Predictions on the train set**</font>

# %%
# Predictions on the train set
y_train_pred = logistic_bal_smote_model.predict(X_train_smote)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_train_smote, y_train_pred)
print(confusion)
# Out:
# [[221911   5538]
#  [ 17693 209756]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_train_smote, y_train_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))
# Out:
# Accuracy:- 0.9489314087993352
# Precision:- 0.9742770351240629
# Recall:- 0.9222111330452102

# %%
# classification_report
print(classification_report(y_train_smote, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95    227449
#            1       0.97      0.92      0.95    227449
#
#     accuracy                           0.95    454898
#    macro avg       0.95      0.95      0.95    454898
# weighted avg       0.95      0.95      0.95    454898

# %%
# Predicted probability
y_train_pred_proba_log_bal_smote = logistic_bal_smote_model.predict_proba(X_train_smote)[:,1]

# %%
# Plot the ROC curve
draw_roc(y_train_smote, y_train_pred_proba_log_bal_smote)

# %% [markdown]
# <font size="3">**Predictions on the test set**</font>

# %%
# Prediction on the test set
y_test_pred = logistic_bal_smote_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[55416  1450]
#  [   10    86]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))
# Out:
# Accuracy:- 0.9743688774972789
# Precision:- 0.055989583333333336
# Recall:- 0.8958333333333334

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     56866
#            1       0.06      0.90      0.11        96
#
#     accuracy                           0.97     56962
#    macro avg       0.53      0.94      0.55     56962
# weighted avg       1.00      0.97      0.99     56962

# %%
# Predicted probability
y_test_pred_proba = logistic_bal_smote_model.predict_proba(X_test)[:,1]

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# <font size="4">**Model summary - Logistic Regression with SMOTE**</font>
#
# - <font size="4">**Train set**</font>
#
#     - <font size="3">Accuracy:- 0.948</font>
#
#     - <font size="3">Precision:- 0.974</font>
#
#     - <font size="3">Recall:- 0.922</font>
#
#     - <font size="3">ROC :- 0.99</font>
#
#
# - <font size="3">**Test set**</font>
#
#     - <font size="3">Accuracy:- 0.974</font>
#
#     - <font size="3">Precision:- 0.056</font>
#
#     - <font size="3">Recall:- 0.896</font>
#
#     - <font size="3">ROC :- 0.97</font>

# %% [markdown]
# <font size="4" >**2. XGBoost**</font>

# %% [markdown]
# <font size="4">**2a. Tuning hyperparameters**</font>

# %%
# hyperparameter tuning with XGBoost

# creating a KFold object 
folds = 3

# specify range of hyperparameters
param_grid = {'learning_rate': [0.2, 0.6], 
             'subsample': [0.3, 0.6, 0.9]}          


# specify model
xgb_model = XGBClassifier(max_depth=2, n_estimators=200)

# set up GridSearchCV()
model_cv = GridSearchCV(estimator = xgb_model, 
                        param_grid = param_grid, 
                        scoring= 'roc_auc', 
                        cv = folds, 
                        verbose = 1,
                        return_train_score=True)      

# fit the model
model_cv.fit(X_train_smote, y_train_smote)
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      gamma=None, gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_bin=None,
#                                      max_ca...one,
#                                      max_delta_step=None, max_depth=2,
#                                      max_leaves=None, min_child_weight=None,
# ...

# %%
# cv results
cv_results = pd.DataFrame(model_cv.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      11.384569      0.146065         0.084482        0.000661
# 1      15.902321      0.273587         0.083009        0.003816
# 2      17.026857      0.118200         0.080643        0.000423
# 3      11.330596      0.106640         0.083824        0.002385
# 4      15.820474      0.146853         0.083351        0.002069
# 5      17.244010      0.086537         0.082643        0.003475
#
#   param_learning_rate param_subsample  \
# 0                 0.2             0.3
# 1                 0.2             0.6
# 2                 0.2             0.9
# 3                 0.6             0.3
# 4                 0.6             0.6
# 5                 0.6             0.9
#
#                                      params  split0_test_score  \
# 0  {'learning_rate': 0.2, 'subsample': 0.3}           0.999645
# 1  {'learning_rate': 0.2, 'subsample': 0.6}           0.999671
# ...

# %%
# # plotting
plt.figure(figsize=(16,6))

param_grid = {'learning_rate': [0.2, 0.6], 
             'subsample': [0.3, 0.6, 0.9]} 


for n, subsample in enumerate(param_grid['subsample']):
    

    # subplot 1/n
    plt.subplot(1,len(param_grid['subsample']), n+1)
    df = cv_results[cv_results['param_subsample']==subsample]

    plt.plot(df["param_learning_rate"], df["mean_test_score"])
    plt.plot(df["param_learning_rate"], df["mean_train_score"])
    plt.xlabel('learning_rate')
    plt.ylabel('AUC')
    plt.title("subsample={0}".format(subsample))
    plt.ylim([0.60, 1])
    plt.legend(['test score', 'train score'], loc='upper left')
    plt.xscale('log')

# %%
model_cv.best_params_
# Out:
# {'learning_rate': 0.6, 'subsample': 0.9}

# %% [markdown]
# We see that the train score almost touches to 1. Among the hyperparameters, we can choose the best parameters as learning_rate : 0.6 and subsample: 0.9.

# %% [markdown]
# <font size="4">**2b. XGBoost model with optimal hyperparameters**</font>

# %%
# chosen hyperparameters
# 'objective':'binary:logistic' outputs probability rather than label, which we need for calculating auc
params = {'learning_rate': 0.6,
          'max_depth': 2, 
          'n_estimators':200,
          'subsample':0.9,
         'objective':'binary:logistic'}

# fit model on training data
xgb_bal_smote_model = XGBClassifier(params = params)
xgb_bal_smote_model.fit(X_train_smote, y_train_smote)
# Out:
# [18:05:54] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-37/xgboost/src/learner.cc:627:
# Parameters: { "params" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
# ...

# %% [markdown]
# <font size="3">**Predictions on the train set**</font>

# %%
# Predictions on the train set
y_train_pred = xgb_bal_smote_model.predict(X_train_smote)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_train_smote, y_train_pred)
print(confusion)
# Out:
# [[227447      2]
#  [     0 227449]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_train_smote, y_train_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))
# Out:
# Accuracy:- 0.9999956034099952
# Precision:- 0.9999912068973098
# Recall:- 1.0

# %%
# classification_report
print(classification_report(y_train_smote, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227449
#            1       1.00      1.00      1.00    227449
#
#     accuracy                           1.00    454898
#    macro avg       1.00      1.00      1.00    454898
# weighted avg       1.00      1.00      1.00    454898

# %%
# Predicted probability
y_train_pred_proba = xgb_bal_smote_model.predict_proba(X_train_smote)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_train_smote, y_train_pred_proba)
auc
# Out:
# 1.0

# %%
# Plot the ROC curve
draw_roc(y_train_smote, y_train_pred_proba)

# %% [markdown]
# <font size="3">**Predictions on the test set**</font>

# %%
# Predictions on the test set
y_test_pred = xgb_bal_smote_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[56839    27]
#  [   20    76]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))
# Out:
# Accuracy:- 0.9991748885221726
# Precision:- 0.7378640776699029
# Recall:- 0.7916666666666666

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56866
#            1       0.74      0.79      0.76        96
#
#     accuracy                           1.00     56962
#    macro avg       0.87      0.90      0.88     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
# Predicted probability
y_test_pred_proba = xgb_bal_smote_model.predict_proba(X_test)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_test, y_test_pred_proba)
auc
# Out:
# 0.9618437789423088

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# <font size="4">**Model summary - XGBoost with SMOTE**</font>
#
# - <font size="4">**Train set**</font>
#
#     - <font size="3">Accuracy:- 1.0</font>
#
#     - <font size="3">Precision:- 1.0</font>
#
#     - <font size="3">Recall:- 1.0</font>
#
#     - <font size="3">ROC :- 1.0</font>
#
#
# - <font size="3">**Test set**</font>
#
#     - <font size="3">Accuracy:- 0.999</font>
#
#     - <font size="3">Precision:- 0.738</font>
#
#     - <font size="3">Recall:- 0.792</font>
#
#     - <font size="3">ROC :- 0.96</font>

# %% [markdown]
# <font size="4" >**3. Decision Tree**</font>

# %% [markdown]
# <font size="4">**3a. Tuning hyperparameters**</font>

# %%
# Create the parameter grid 
param_grid = {
    'max_depth': range(5, 15, 5),
    'min_samples_leaf': range(50, 150, 50),
    'min_samples_split': range(50, 150, 50),
}


# Instantiate the grid search model
dtree = DecisionTreeClassifier()

grid_search = GridSearchCV(estimator = dtree, 
                           param_grid = param_grid, 
                           scoring= 'roc_auc',
                           cv = 3, 
                           verbose = 1)

# Fit the grid search to the data
grid_search.fit(X_train_smote,y_train_smote)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': range(5, 15, 5),
#                          'min_samples_leaf': range(50, 150, 50),
#                          'min_samples_split': range(50, 150, 50)},
#              scoring='roc_auc', verbose=1)

# %%
# cv results
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       4.650609      0.028851         0.025972        0.000052
# 1       4.609993      0.011909         0.025567        0.000296
# 2       4.596604      0.005573         0.025260        0.000175
# 3       4.600253      0.024710         0.025555        0.000343
# 4       8.447801      0.048600         0.027794        0.000293
# 5       8.498315      0.026565         0.027986        0.000777
# 6       8.453260      0.099658         0.027855        0.000173
# 7       8.392287      0.037001         0.028194        0.000152
#
#   param_max_depth param_min_samples_leaf param_min_samples_split  \
# 0               5                     50                      50
# 1               5                     50                     100
# 2               5                    100                      50
# 3               5                    100                     100
# ...

# %%
# Printing the optimal sensitivity score and hyperparameters
print("Best roc_auc:-", grid_search.best_score_)
print(grid_search.best_estimator_)
# Out:
# Best roc_auc:- 0.9980909065508111
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=50, min_samples_split=100)

# %% [markdown]
# <font size="4">**3b. Decision Tree with optimal hyperparameters**</font>

# %%
# Model with optimal hyperparameters
dt_bal_smote_model = DecisionTreeClassifier(criterion = "gini", 
                                  random_state = 100,
                                  max_depth=10, 
                                  min_samples_leaf=50,
                                  min_samples_split=100)

dt_bal_smote_model.fit(X_train_smote, y_train_smote)
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=50, min_samples_split=100,
#                        random_state=100)

# %% [markdown]
# <font size="3">**Predictions on the train set**</font>

# %%
# Predictions on the train set
y_train_pred = dt_bal_smote_model.predict(X_train_smote)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_train_smote, y_train_pred)
print(confusion)
# Out:
# [[223809   3640]
#  [  2374 225075]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_train_smote, y_train_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))
# Out:
# Accuracy:- 0.9867794538555896
# Precision:- 0.9840849966115034
# Recall:- 0.9895624953286232

# %%
# classification_report
print(classification_report(y_train_smote, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99    227449
#            1       0.98      0.99      0.99    227449
#
#     accuracy                           0.99    454898
#    macro avg       0.99      0.99      0.99    454898
# weighted avg       0.99      0.99      0.99    454898

# %%
# Predicted probability
y_train_pred_proba = dt_bal_smote_model.predict_proba(X_train_smote)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_train_smote, y_train_pred_proba)
auc
# Out:
# 0.9986355757920081

# %%
# Plot the ROC curve
draw_roc(y_train_smote, y_train_pred_proba)

# %% [markdown]
# <font size="3">**Predictions on the test set**</font>

# %%
# Predictions on the test set
y_test_pred = dt_bal_smote_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[55852  1014]
#  [   19    77]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Precision
print("Precision:-", TP / float(TP+FP))

# Recall
print("Recall:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))
# Out:
# Accuracy:- 0.9818651030511569
# Precision:- 0.07057745187901009
# Recall:- 0.8020833333333334
# Specificity:- 0.9821686069004326

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56866
#            1       0.07      0.80      0.13        96
#
#     accuracy                           0.98     56962
#    macro avg       0.54      0.89      0.56     56962
# weighted avg       1.00      0.98      0.99     56962

# %%
# Predicted probability
y_test_pred_proba = dt_bal_smote_model.predict_proba(X_test)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_test, y_test_pred_proba)
auc
# Out:
# 0.8551876157692353

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# <font size="4">**Model summary - Decision Tree with SMOTE**</font>
#
# - <font size="4">**Train set**</font>
#
#     - <font size="3">Accuracy:- 0.987</font>
#
#     - <font size="3">Precision:- 0.984</font>
#
#     - <font size="3">Recall:- 0.99</font>
#
#     - <font size="3">ROC :- 1.0</font>
#
#
# - <font size="3">**Test set**</font>
#
#     - <font size="3">Accuracy:- 0.982</font>
#
#     - <font size="3">Precision:- 0.071</font>
#
#     - <font size="3">Recall:- 0.802</font>
#
#     - <font size="3">ROC :- 0.86</font>

# %% [markdown]
# **Choosing best model on the balanced data**
#
# Here we balanced the data with various approach such as Undersampling, Oversampling, SMOTE and Adasy. With every data balancing thechnique we built several models such as Logistic, XGBoost, Decision Tree, and Random Forest.
#
# We can see that almost all the models performed more or less good. But we should be interested in the best model.
#
# Though the Undersampling technique models performed well, we should keep mind that by doing the undersampling some imformation were lost. Hence, it is better not to consider the undersampling models.
#
# Whereas the SMOTE and Adasyn models performed well. Among those models the simplist model Logistic regression has ROC score 0.99 in the train set and 0.97 on the test set. We can consider the Logistic model as the best model to choose because of the easy interpretation of the models and also the resourse requirements to build the mdoel is lesser than the other heavy models such as Random forest or XGBoost.
#
# Hence, we can conclude that the Logistic regression model with SMOTE is the best model for its simlicity and less resource requirement.

# %% [markdown]
# **Print the FPR,TPR & select the best threshold from the roc curve for the best model**

# %%
print('Train auc =', metrics.roc_auc_score(y_train_smote, y_train_pred_proba_log_bal_smote))
fpr, tpr, thresholds = metrics.roc_curve(y_train_smote, y_train_pred_proba_log_bal_smote)
threshold = thresholds[np.argmax(tpr-fpr)]
print("Threshold=",threshold)
# Out:
# Train auc = 0.9897539730388945
# Threshold= 0.5311563617203277

# %% [markdown]
# We can see that the threshold is 0.53, for which the TPR is the highest and FPR is the lowest and we got the best ROC score.

# %% [markdown]
# **After Model Training - Threshold Adjustment to Optimize F1**
#
# It's key to remember that predicting 1 when our model spits out 𝑝>.50 and 0 when 𝑝<.50 is a design choice that focuses on accuracy rather than being something we're locked into.
#
# If our focus is on a different metric like 𝐹1 or an 𝐹𝛽 variant, 50% could easily be the wrong threshold to use! If we become more aggressive in predicting positives and lower our 𝑝 threshold, it's possible that our recall will improve enough to offset our decline in precision, increasing our 𝐹 score.
#
# As with everything else, our decision threshold should be something we tune with validation/CV and should not be taken for granted. A nice way to do this is to pull out explicit model probabilities using predict_proba, then loop through a range of possible thresholds 𝑝 and score the corresponding predictions. Then we can grab the max F1 score and the threshold that produced that score.

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score

import seaborn as sns
sns.set()

X_val, y_val = X_test, y_test

thresh_ps = np.linspace(.10,.95,1000)
model_val_probs = logistic_bal_smote_model.predict_proba(X_val)[:,1] 

f1_scores, prec_scores, rec_scores, acc_scores = [], [], [], []
for p in thresh_ps:
    model_val_labels = model_val_probs >= p
    f1_scores.append(f1_score(y_val, model_val_labels))    
    prec_scores.append(precision_score(y_val, model_val_labels))
    rec_scores.append(recall_score(y_val, model_val_labels))
    acc_scores.append(accuracy_score(y_val, model_val_labels))
    
plt.plot(thresh_ps, f1_scores)
plt.plot(thresh_ps, prec_scores)
plt.plot(thresh_ps, rec_scores)
plt.plot(thresh_ps, acc_scores)

plt.title('Metric Scores vs. Positive Class Decision Probability Threshold')
plt.legend(['F1','Precision','Recall','Accuracy'], bbox_to_anchor=(1.05, 0), loc='lower left')
plt.xlabel('P threshold')
plt.ylabel('Metric score')

best_f1_score = np.max(f1_scores) 
best_thresh_p = thresh_ps[np.argmax(f1_scores)]

print('Logistic Regression Model best F1 score %.3f at prob decision threshold >= %.3f' 
      % (best_f1_score, best_thresh_p))
# Out:
# Logistic Regression Model best F1 score 0.503 at prob decision threshold >= 0.950

# %% [markdown]
# **Cost benefit analysis**
#
# We have tried several models till now with both balanced and imbalanced data. We have noticed most of the models have performed more or less well in terms of ROC score, Precision and Recall.
#
# But while picking the best model we should consider few things such as whether we have required infrastructure, resources or computational power to run the model or not. For the models such as Random forest, SVM, XGBoost we require heavy computational resources and eventually to build that infrastructure the cost of deploying the model increases. On the other hand the simpler model such as Logistic regression requires less computational resources, so the cost of building the model is less.
#
# We also have to consider that for little change of the ROC score how much monetary loss of gain the bank incur. If the amount if huge then we have to consider building the complex model even though the cost of building the model is high.

# %% [markdown]
# **Summary to the business**
#
# For banks with smaller average transaction value, we would want high precision because we only want to label relevant transactions as fraudulent. For every transaction that is flagged as fraudulent, we can add the human element to verify whether the transaction was done by calling the customer. However, when precision is low, such tasks are a burden because the human element has to be increased.
#
# For banks having a larger transaction value, if the recall is low, i.e., it is unable to detect transactions that are labelled as non-fraudulent. So we have to consider the losses if the missed transaction was a high-value fraudulent one.
#
# So here, to save the banks from high-value fraudulent transactions, we have to focus on a high recall in order to detect actual fraudulent transactions.
#
# After performing several models, we have seen that in the balanced dataset with SMOTE technique the simplest Logistic regression model has good ROC score and also high Recall. Hence, we can go with the logistic model here. It is also easier to interpret and explain to the business.
